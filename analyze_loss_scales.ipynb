# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
metrics = pd.read_csv('lightning_logs/version_0/metrics.csv')

# rolling mean impute missing values
metrics = metrics.ffill().bfill()
metrics.describe()

# Plot the loss all columns that have the word loss (after the 50 first steps)
losses = metrics.filter(like='loss', axis=1).iloc[0:]
# scale columns to have mean 0 and std 1
losses = (losses - losses.mean()) / losses.std()
losses = losses.rolling(100).mean()
losses.plot(figsize=(10, 10))
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over epochs')
plt.show()
# Out:
#           bce_loss    dice_loss        epoch       kl_loss      lr-Adam  \
# count  4024.000000  4024.000000  4024.000000   4024.000000  4024.000000
# mean      0.193031     0.587066     7.497266     27.689974     0.000042
# std       0.070101     0.208847     4.610344   1241.741096     0.000034
# min       0.077766     0.312854     0.000000      0.000004     0.000000
# 25%       0.150830     0.481414     3.000000      0.001552     0.000010
# 50%       0.179392     0.541159     7.000000      0.002090     0.000035
# 75%       0.215869     0.621560    11.000000      0.002460     0.000069
# max       0.921234     2.495011    15.000000  55705.625000     0.000100
#
#        reconstruction_loss         step    train_loss  tversky_loss  \
# count          4024.000000  4024.000000   4024.000000   4024.000000
# mean           1382.389008   999.994036    142.254545      0.583186
# std            3649.733662   577.448213    441.792995      0.235400
# ...
