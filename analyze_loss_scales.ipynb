# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
metrics = pd.read_csv('lightning_logs/version_41/metrics.csv')

# rolling mean impute missing values
metrics = metrics.ffill().bfill()
metrics.describe()

# Plot the loss all columns that have the word loss (after the 50 first steps)
losses = metrics.filter(like='val', axis=1)
# scale columns to have mean 0 and std 1
losses = (losses - losses.mean()) / losses.std()
losses = losses.rolling(10).mean()
losses.plot(figsize=(10, 10))
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over epochs')
plt.show()
# Out:
# /home/paperspace/DMI2024B/.venv/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/paperspace/DMI2024B/.venv/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/paperspace/DMI2024B/.venv/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
